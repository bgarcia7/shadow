# %%
import urllib
from urllib2 import urlopen
import matplotlib.pyplot as plt
from pymongo import MongoClient
from bs4 import BeautifulSoup
from collections import defaultdict
from bson.objectid import ObjectId
# %matplotlib inline

db_client = MongoClient()
data = db_client['shopify']['forum']
data2 = db_client['shopify_backup']
users = db_client['shopify']['users']
post_db = db_client['shopify']['posts']
shopify_post_db = db_client['shopify']['shopify_posts']

# %%
base_url = 'https://ecommerce.shopify.com/'
forums_url = 'forums'

# %% [markdown]
# <div style="text-align:center;padding:10px;"><h1>Step 3: Scrape User and Topic Information</h1></div>

# %%
for category in [data.find({'category':'category-shopify-discussion'})[0]]:
    
    print '-----> CATEGORY:', category['category']
    for sub_cat_key in category["sub_cats"]:
        
        if sub_cat_key == 'category-ecommerce-design':
            
            print 'SUBCATEGORY: {sub_cat}'.format(sub_cat=sub_cat_key)


            sub_cat = category['sub_cats'][sub_cat_key]
            posts = []


            # Run through each thread
            for idx, url in enumerate(sub_cat['topic_urls']):

                if idx > 9540 and idx <= 11000:
                    try:
                        topic_page = BeautifulSoup(urlopen(url))
                        thread = []

                        # Process original post
                        user_id, text, date = process_post(topic_page.find('div',{'class':'original-post'}))
                        shopify_post_db.insert_one({'user_id':user_id, 'date':date, 'text':text})

                        # Process each reply
                        for reply in topic_page.find_all('div',{'itemtype':'http://schema.org/UserComments'}):
                            user_id, text, date = process_post(reply)
                            shopify_post_db.insert_one({'user_id':user_id, 'date':date, 'text':text})


                        # Status Update
                        if (idx+1) % 5 == 0:
                            print 'PROCESSED {idx}/{total} posts'.format(idx=(idx+1),total=len(sub_cat['topic_urls']))

                    except Exception as e:
                        print 'ERROR IN SUBCATEGORY: ', str(e)
# Out:
# -----> CATEGORY: category-shopify-discussion
# SUBCATEGORY: category-ecommerce-design
# PROCESSED 9545/20620 posts
# PROCESSED 9550/20620 posts
# PROCESSED 9555/20620 posts
# PROCESSED 9560/20620 posts
# PROCESSED 9565/20620 posts
# PROCESSED 9570/20620 posts
# PROCESSED 9575/20620 posts
# PROCESSED 9580/20620 posts
# PROCESSED 9585/20620 posts
# PROCESSED 9590/20620 posts
# PROCESSED 9595/20620 posts
# PROCESSED 9600/20620 posts
# PROCESSED 9605/20620 posts
# PROCESSED 9610/20620 posts
# PROCESSED 9615/20620 posts
# PROCESSED 9620/20620 posts
# PROCESSED 9625/20620 posts
# PROCESSED 9630/20620 posts
# PROCESSED 9635/20620 posts
# PROCESSED 9640/20620 posts
# PROCESSED 9645/20620 posts
# PROCESSED 9650/20620 posts
# PROCESSED 9655/20620 posts
# PROCESSED 9660/20620 posts
# PROCESSED 9665/20620 posts
# PROCESSED 9670/20620 posts
# PROCESSED 9675/20620 posts
# PROCESSED 9680/20620 posts
# PROCESSED 9685/20620 posts
# PROCESSED 9690/20620 posts
# PROCESSED 9695/20620 posts
# PROCESSED 9700/20620 posts
# PROCESSED 9705/20620 posts
# PROCESSED 9710/20620 posts
# PROCESSED 9715/20620 posts
# PROCESSED 9720/20620 posts
# PROCESSED 9725/20620 posts
# PROCESSED 9730/20620 posts
# PROCESSED 9735/20620 posts
# PROCESSED 9740/20620 posts
# PROCESSED 9745/20620 posts
# PROCESSED 9750/20620 posts
# PROCESSED 9755/20620 posts
# PROCESSED 10725/20620 posts
# PROCESSED 10730/20620 posts
# PROCESSED 10735/20620 posts
# PROCESSED 10740/20620 posts
# PROCESSED 10745/20620 posts
# PROCESSED 10750/20620 posts
# PROCESSED 10755/20620 posts
# PROCESSED 10760/20620 posts
# PROCESSED 10765/20620 posts
# PROCESSED 10770/20620 posts
# PROCESSED 10775/20620 posts
# PROCESSED 10780/20620 posts
# PROCESSED 10785/20620 posts
# PROCESSED 10790/20620 posts
# PROCESSED 10795/20620 posts
# PROCESSED 10800/20620 posts
# PROCESSED 10805/20620 posts
# PROCESSED 10810/20620 posts
# PROCESSED 10815/20620 posts
# PROCESSED 10820/20620 posts
# PROCESSED 10825/20620 posts
# PROCESSED 10830/20620 posts
# PROCESSED 10835/20620 posts
# PROCESSED 10840/20620 posts
# PROCESSED 10845/20620 posts
# PROCESSED 10850/20620 posts
# PROCESSED 10855/20620 posts
# PROCESSED 10860/20620 posts
# PROCESSED 10865/20620 posts
# PROCESSED 10870/20620 posts
# PROCESSED 10875/20620 posts
# PROCESSED 10880/20620 posts
# PROCESSED 10885/20620 posts
# PROCESSED 10890/20620 posts
# PROCESSED 10895/20620 posts
# PROCESSED 10900/20620 posts
# PROCESSED 10905/20620 posts
# PROCESSED 10910/20620 posts
# PROCESSED 10915/20620 posts
# PROCESSED 10920/20620 posts
# PROCESSED 10925/20620 posts
# PROCESSED 10930/20620 posts
# PROCESSED 10935/20620 posts
# PROCESSED 10940/20620 posts
# PROCESSED 10945/20620 posts
# PROCESSED 10950/20620 posts
# PROCESSED 10955/20620 posts
# PROCESSED 10960/20620 posts
# PROCESSED 10965/20620 posts
# PROCESSED 10970/20620 posts
# PROCESSED 10975/20620 posts
# PROCESSED 10980/20620 posts
# PROCESSED 10985/20620 posts
# PROCESSED 10990/20620 posts
# PROCESSED 10995/20620 posts
# PROCESSED 11000/20620 posts

# %%
def process_post(post):
    
    user = post.find('div',{'class':'author'})
    user_id = int(user.find('a',{'class':'username'}).get('href').split('/')[-1])
    
    # Add user to db if does not exist 
    if users.find({'id': user_id}).count() < 1:
        name = user.find('a',{'class':'username'}).text.strip()
        title = user.find_all('em')[0].text.strip().lower()
        site = user.find_all('em')[-1].text.strip().lower()
        posts = int(user.find('div',{'class':'stats'}).find('a').text.strip().lower())
        users.insert_one({'id':user_id,'name':name,'title':title,'site':site, 'posts':posts })
        
    # Extract date
    date = get_date(post)
    
    # Extract text
    text = ' '.join([txt.text.lower() for txt in post.find('div',{'itemprop':'description'}).find_all('p')])
    
    return user_id, text, date

# %%
import re
import datetime as dt
months = ['january','february','march','april','may','june','july','august','september','october','november','december']

def get_date(post):
    
    regexes = ['(\d+) day','(\d+) month', '(\w+) (\d+), (20\d+)']
    raw_date = post.find('div',{'class':'date'}).text.strip()
    date = None
    
    for idx, reg in enumerate(regexes):
        matches = re.search(reg, raw_date)
        if matches:
            if idx == 0:
                date = dt.datetime.now() - dt.timedelta(days=int(matches.group(1)))
            elif idx == 1:
                date = dt.datetime.now() - dt.timedelta(days=int(matches.group(1))*30)
            else:
                date = dt.datetime(int(matches.group(3)), int(months.index(matches.group(1).lower())) + 1, int(matches.group(2)))

    return date.strftime('%Y-%m-%d') if date else 'WHY'
