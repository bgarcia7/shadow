# %%
import urllib
from urllib2 import urlopen
import matplotlib.pyplot as plt
from pymongo import MongoClient
from bs4 import BeautifulSoup
from collections import defaultdict
from bson.objectid import ObjectId
# %matplotlib inline

db_client = MongoClient()
data = db_client['shopify']['forum']
data2 = db_client['shopify_backup']
users = db_client['shopify']['users']
post_db = db_client['shopify']['posts']
shopify_post_db = db_client['shopify']['shopify_posts']

# %%
base_url = 'https://ecommerce.shopify.com/'
forums_url = 'forums'

# %% [markdown]
# <div style="text-align:center;padding:10px;"><h1>Step 3: Scrape User and Topic Information</h1></div>

# %%
for category in [data.find({'category':'category-shopify-discussion'})[0]]:
    
    print '-----> CATEGORY:', category['category']
    for sub_cat_key in category["sub_cats"]:
        print sub_cat_key
        
        if sub_cat_key == 'category-shopify-discussion':
            
            print 'SUBCATEGORY: {sub_cat}'.format(sub_cat=sub_cat_key)


            sub_cat = category['sub_cats'][sub_cat_key]
            posts = []


            # Run through each thread
            for idx, url in enumerate(sub_cat['topic_urls']):

                if idx > 8455 and idx < 11000:
                    try:
                        topic_page = BeautifulSoup(urlopen(url))
                        thread = []

                        # Process original post
                        user_id, text, date = process_post(topic_page.find('div',{'class':'original-post'}))
                        shopify_post_db.insert_one({'user_id':user_id, 'date':date, 'text':text})

                        # Process each reply
                        for reply in topic_page.find_all('div',{'itemtype':'http://schema.org/UserComments'}):
                            user_id, text, date = process_post(reply)
                            shopify_post_db.insert_one({'user_id':user_id, 'date':date, 'text':text})


                        # Status Update
                        if (idx+1) % 5 == 0:
                            print 'PROCESSED {idx}/{total} posts'.format(idx=(idx+1),total=len(sub_cat['topic_urls']))

                    except Exception as e:
                        print 'ERROR IN SUBCATEGORY: ', str(e)
# Out:
# -----> CATEGORY: category-shopify-discussion
# category-shopify-point-of-sale
# category-shopify-job-board
# category-scripts
# category-shopify-apps
# category-shopify-mobile
# category-api-announcements
# category-shopify-apis-and-technology
# category-ecommerce-design
# category-shopify-discussion
# SUBCATEGORY: category-shopify-discussion
# /Users/brandongarcia/miniconda2/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /Users/brandongarcia/miniconda2/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))
# PROCESSED 8460/15380 posts
# PROCESSED 8465/15380 posts
# PROCESSED 8470/15380 posts
# PROCESSED 8475/15380 posts
# PROCESSED 8480/15380 posts
# PROCESSED 8485/15380 posts
# PROCESSED 8490/15380 posts
# PROCESSED 8495/15380 posts
# PROCESSED 8500/15380 posts
# PROCESSED 8505/15380 posts
# PROCESSED 8510/15380 posts
# PROCESSED 8515/15380 posts
# PROCESSED 8520/15380 posts
# PROCESSED 8525/15380 posts
# PROCESSED 8530/15380 posts
# PROCESSED 8535/15380 posts
# PROCESSED 8540/15380 posts
# PROCESSED 8545/15380 posts
# PROCESSED 8550/15380 posts
# PROCESSED 8555/15380 posts
# PROCESSED 8560/15380 posts
# PROCESSED 8565/15380 posts
# PROCESSED 8570/15380 posts
# PROCESSED 8575/15380 posts
# PROCESSED 8580/15380 posts
# PROCESSED 8585/15380 posts
# PROCESSED 8590/15380 posts
# PROCESSED 8595/15380 posts
# PROCESSED 8600/15380 posts
# PROCESSED 8605/15380 posts
# PROCESSED 8610/15380 posts
# PROCESSED 8615/15380 posts
# PROCESSED 8620/15380 posts
# PROCESSED 8625/15380 posts
# PROCESSED 8630/15380 posts
# PROCESSED 8635/15380 posts
# PROCESSED 8640/15380 posts
# PROCESSED 8645/15380 posts
# PROCESSED 8650/15380 posts
# PROCESSED 8655/15380 posts
# PROCESSED 8660/15380 posts
# PROCESSED 8665/15380 posts
# PROCESSED 8670/15380 posts
# PROCESSED 8675/15380 posts
# PROCESSED 8680/15380 posts
# PROCESSED 8685/15380 posts
# PROCESSED 8690/15380 posts
# PROCESSED 8695/15380 posts
# PROCESSED 8700/15380 posts
# PROCESSED 8705/15380 posts
# PROCESSED 8710/15380 posts
# PROCESSED 8715/15380 posts
# PROCESSED 8720/15380 posts
# PROCESSED 8725/15380 posts
# PROCESSED 8730/15380 posts
# PROCESSED 8735/15380 posts
# PROCESSED 8740/15380 posts
# PROCESSED 8745/15380 posts
# PROCESSED 8750/15380 posts
# PROCESSED 8755/15380 posts
# PROCESSED 8760/15380 posts
# PROCESSED 8765/15380 posts
# PROCESSED 8770/15380 posts
# PROCESSED 8775/15380 posts
# PROCESSED 8780/15380 posts
# PROCESSED 8785/15380 posts
# PROCESSED 8790/15380 posts
# PROCESSED 8795/15380 posts
# PROCESSED 8800/15380 posts
# PROCESSED 8805/15380 posts
# PROCESSED 8810/15380 posts
# PROCESSED 8815/15380 posts
# PROCESSED 8820/15380 posts
# PROCESSED 8825/15380 posts
# PROCESSED 8830/15380 posts
# PROCESSED 8835/15380 posts
# PROCESSED 8840/15380 posts
# PROCESSED 8845/15380 posts
# PROCESSED 8850/15380 posts
# PROCESSED 8855/15380 posts
# PROCESSED 8860/15380 posts
# PROCESSED 8865/15380 posts
# PROCESSED 8870/15380 posts
# PROCESSED 8875/15380 posts
# PROCESSED 8880/15380 posts
# PROCESSED 8885/15380 posts
# PROCESSED 8890/15380 posts
# PROCESSED 8895/15380 posts
# PROCESSED 8900/15380 posts
# PROCESSED 8905/15380 posts
# PROCESSED 8910/15380 posts
# PROCESSED 8915/15380 posts
# PROCESSED 8920/15380 posts
# PROCESSED 8925/15380 posts
# PROCESSED 8930/15380 posts
# PROCESSED 8935/15380 posts
# PROCESSED 8940/15380 posts
# PROCESSED 8945/15380 posts
# PROCESSED 8950/15380 posts
# PROCESSED 8955/15380 posts
# PROCESSED 8960/15380 posts
# PROCESSED 8965/15380 posts
# PROCESSED 8970/15380 posts
# PROCESSED 8975/15380 posts
# PROCESSED 8980/15380 posts
# PROCESSED 8985/15380 posts
# PROCESSED 8990/15380 posts
# PROCESSED 8995/15380 posts
# PROCESSED 9000/15380 posts
# PROCESSED 9005/15380 posts
# PROCESSED 9010/15380 posts
# PROCESSED 9015/15380 posts
# PROCESSED 9020/15380 posts
# PROCESSED 9025/15380 posts
# PROCESSED 9030/15380 posts
# PROCESSED 9035/15380 posts
# PROCESSED 9040/15380 posts
# PROCESSED 9045/15380 posts
# PROCESSED 9050/15380 posts
# PROCESSED 9055/15380 posts
# PROCESSED 9060/15380 posts
# PROCESSED 9065/15380 posts
# PROCESSED 9070/15380 posts
# PROCESSED 9075/15380 posts
# PROCESSED 9080/15380 posts
# PROCESSED 9085/15380 posts
# PROCESSED 9090/15380 posts
# PROCESSED 9095/15380 posts
# PROCESSED 9100/15380 posts
# PROCESSED 9105/15380 posts
# PROCESSED 9110/15380 posts
# PROCESSED 9115/15380 posts
# PROCESSED 9120/15380 posts
# PROCESSED 9125/15380 posts
# PROCESSED 9130/15380 posts
# PROCESSED 9135/15380 posts
# PROCESSED 9140/15380 posts
# PROCESSED 9145/15380 posts
# PROCESSED 9150/15380 posts
# PROCESSED 9155/15380 posts
# PROCESSED 9160/15380 posts
# PROCESSED 9165/15380 posts
# PROCESSED 9170/15380 posts
# PROCESSED 9175/15380 posts
# PROCESSED 9180/15380 posts
# PROCESSED 9185/15380 posts
# PROCESSED 9190/15380 posts
# PROCESSED 9195/15380 posts
# PROCESSED 9200/15380 posts
# PROCESSED 9205/15380 posts
# PROCESSED 9210/15380 posts
# PROCESSED 9215/15380 posts
# PROCESSED 9220/15380 posts
# PROCESSED 9225/15380 posts
# PROCESSED 9230/15380 posts
# PROCESSED 9235/15380 posts
# PROCESSED 9240/15380 posts
# PROCESSED 9245/15380 posts
# PROCESSED 9250/15380 posts
# PROCESSED 9255/15380 posts
# PROCESSED 9260/15380 posts
# PROCESSED 9265/15380 posts
# PROCESSED 9270/15380 posts
# PROCESSED 9275/15380 posts
# PROCESSED 9280/15380 posts
# PROCESSED 9285/15380 posts
# PROCESSED 9290/15380 posts
# PROCESSED 9295/15380 posts
# PROCESSED 9300/15380 posts
# PROCESSED 9305/15380 posts
# PROCESSED 9310/15380 posts
# PROCESSED 9315/15380 posts
# PROCESSED 9320/15380 posts
# PROCESSED 9325/15380 posts
# PROCESSED 9330/15380 posts
# PROCESSED 9335/15380 posts
# PROCESSED 9340/15380 posts
# PROCESSED 9345/15380 posts
# PROCESSED 9350/15380 posts
# PROCESSED 9355/15380 posts
# PROCESSED 9360/15380 posts
# PROCESSED 9365/15380 posts
# PROCESSED 9370/15380 posts
# PROCESSED 9375/15380 posts
# PROCESSED 9380/15380 posts
# PROCESSED 9385/15380 posts
# PROCESSED 9390/15380 posts
# PROCESSED 9395/15380 posts
# PROCESSED 9400/15380 posts
# PROCESSED 9405/15380 posts
# PROCESSED 9410/15380 posts
# PROCESSED 9415/15380 posts
# PROCESSED 9420/15380 posts
# PROCESSED 9425/15380 posts
# PROCESSED 9430/15380 posts
# PROCESSED 9435/15380 posts
# PROCESSED 9440/15380 posts
# PROCESSED 9445/15380 posts
# PROCESSED 9450/15380 posts
# PROCESSED 9455/15380 posts
# PROCESSED 9460/15380 posts
# PROCESSED 9465/15380 posts
# PROCESSED 9470/15380 posts
# PROCESSED 9475/15380 posts
# PROCESSED 9480/15380 posts
# PROCESSED 9485/15380 posts
# PROCESSED 9490/15380 posts
# PROCESSED 9495/15380 posts
# PROCESSED 9500/15380 posts
# PROCESSED 9505/15380 posts
# PROCESSED 9510/15380 posts
# PROCESSED 9515/15380 posts
# PROCESSED 9520/15380 posts
# PROCESSED 9525/15380 posts
# PROCESSED 9530/15380 posts
# PROCESSED 9535/15380 posts
# PROCESSED 9540/15380 posts
# PROCESSED 9545/15380 posts
# PROCESSED 9550/15380 posts
# PROCESSED 9555/15380 posts
# PROCESSED 9560/15380 posts
# PROCESSED 9565/15380 posts
# PROCESSED 9570/15380 posts
# PROCESSED 9575/15380 posts
# PROCESSED 9580/15380 posts
# PROCESSED 9585/15380 posts
# PROCESSED 9590/15380 posts
# PROCESSED 9595/15380 posts
# PROCESSED 9600/15380 posts
# PROCESSED 9605/15380 posts
# PROCESSED 9610/15380 posts
# PROCESSED 9615/15380 posts
# PROCESSED 9620/15380 posts
# PROCESSED 9625/15380 posts
# PROCESSED 9630/15380 posts
# PROCESSED 9635/15380 posts
# PROCESSED 9640/15380 posts
# PROCESSED 9645/15380 posts
# PROCESSED 9650/15380 posts
# PROCESSED 9655/15380 posts
# PROCESSED 9660/15380 posts
# PROCESSED 9665/15380 posts
# PROCESSED 9670/15380 posts
# PROCESSED 9675/15380 posts
# PROCESSED 9680/15380 posts
# PROCESSED 9685/15380 posts
# PROCESSED 9690/15380 posts
# PROCESSED 9695/15380 posts
# PROCESSED 9700/15380 posts
# PROCESSED 9705/15380 posts
# PROCESSED 9710/15380 posts
# PROCESSED 9715/15380 posts
# PROCESSED 9720/15380 posts
# PROCESSED 9725/15380 posts
# PROCESSED 9730/15380 posts
# PROCESSED 9735/15380 posts
# PROCESSED 9740/15380 posts
# PROCESSED 9745/15380 posts
# PROCESSED 9750/15380 posts
# PROCESSED 9755/15380 posts
# PROCESSED 9760/15380 posts
# PROCESSED 9765/15380 posts
# PROCESSED 9770/15380 posts
# PROCESSED 9775/15380 posts
# PROCESSED 9780/15380 posts
# PROCESSED 9785/15380 posts
# PROCESSED 9790/15380 posts
# PROCESSED 9795/15380 posts
# PROCESSED 9800/15380 posts
# PROCESSED 9805/15380 posts
# PROCESSED 9810/15380 posts
# PROCESSED 9815/15380 posts
# PROCESSED 9820/15380 posts
# PROCESSED 9825/15380 posts
# PROCESSED 9830/15380 posts
# PROCESSED 9835/15380 posts
# PROCESSED 9840/15380 posts
# PROCESSED 9845/15380 posts
# PROCESSED 9850/15380 posts
# PROCESSED 9855/15380 posts
# PROCESSED 9860/15380 posts
# PROCESSED 9865/15380 posts
# PROCESSED 9870/15380 posts
# PROCESSED 9875/15380 posts
# PROCESSED 9880/15380 posts
# PROCESSED 9885/15380 posts
# PROCESSED 9890/15380 posts
# PROCESSED 9895/15380 posts
# PROCESSED 9900/15380 posts
# PROCESSED 9905/15380 posts
# PROCESSED 9910/15380 posts
# PROCESSED 9915/15380 posts
# PROCESSED 9920/15380 posts
# PROCESSED 9925/15380 posts
# PROCESSED 9930/15380 posts
# PROCESSED 9935/15380 posts
# PROCESSED 9940/15380 posts
# PROCESSED 9945/15380 posts
# PROCESSED 9950/15380 posts
# PROCESSED 9955/15380 posts
# PROCESSED 9960/15380 posts
# PROCESSED 9965/15380 posts
# PROCESSED 9970/15380 posts
# PROCESSED 9975/15380 posts
# PROCESSED 9980/15380 posts
# PROCESSED 9985/15380 posts
# PROCESSED 9990/15380 posts
# PROCESSED 9995/15380 posts
# PROCESSED 10000/15380 posts
# PROCESSED 10005/15380 posts
# PROCESSED 10010/15380 posts
# PROCESSED 10015/15380 posts
# PROCESSED 10020/15380 posts
# PROCESSED 10025/15380 posts
# PROCESSED 10030/15380 posts
# PROCESSED 10035/15380 posts
# PROCESSED 10040/15380 posts
# PROCESSED 10045/15380 posts
# PROCESSED 10050/15380 posts
# PROCESSED 10055/15380 posts
# PROCESSED 10060/15380 posts
# PROCESSED 10065/15380 posts
# PROCESSED 10070/15380 posts
# PROCESSED 10075/15380 posts
# PROCESSED 10080/15380 posts
# PROCESSED 10085/15380 posts
# PROCESSED 10090/15380 posts
# PROCESSED 10095/15380 posts
# PROCESSED 10100/15380 posts
# PROCESSED 10105/15380 posts
# PROCESSED 10110/15380 posts
# PROCESSED 10115/15380 posts
# PROCESSED 10120/15380 posts
# PROCESSED 10125/15380 posts
# PROCESSED 10130/15380 posts
# PROCESSED 10135/15380 posts
# PROCESSED 10140/15380 posts
# PROCESSED 10145/15380 posts
# PROCESSED 10150/15380 posts
# PROCESSED 10155/15380 posts
# PROCESSED 10160/15380 posts
# PROCESSED 10165/15380 posts
# PROCESSED 10170/15380 posts
# PROCESSED 10175/15380 posts
# PROCESSED 10180/15380 posts
# PROCESSED 10185/15380 posts
# PROCESSED 10190/15380 posts
# PROCESSED 10195/15380 posts
# PROCESSED 10200/15380 posts
# PROCESSED 10205/15380 posts
# PROCESSED 10210/15380 posts
# PROCESSED 10215/15380 posts
# PROCESSED 10220/15380 posts
# PROCESSED 10225/15380 posts
# PROCESSED 10230/15380 posts
# PROCESSED 10235/15380 posts
# PROCESSED 10240/15380 posts
# PROCESSED 10245/15380 posts
# PROCESSED 10250/15380 posts
# PROCESSED 10255/15380 posts
# PROCESSED 10260/15380 posts
# PROCESSED 10265/15380 posts
# PROCESSED 10270/15380 posts
# PROCESSED 10275/15380 posts
# PROCESSED 10280/15380 posts
# PROCESSED 10285/15380 posts
# PROCESSED 10290/15380 posts
# PROCESSED 10295/15380 posts
# PROCESSED 10300/15380 posts
# PROCESSED 10305/15380 posts
# PROCESSED 10310/15380 posts
# PROCESSED 10315/15380 posts
# PROCESSED 10320/15380 posts
# PROCESSED 10325/15380 posts
# PROCESSED 10330/15380 posts
# PROCESSED 10335/15380 posts
# PROCESSED 10340/15380 posts
# PROCESSED 10345/15380 posts
# PROCESSED 10350/15380 posts
# PROCESSED 10355/15380 posts
# PROCESSED 10360/15380 posts
# PROCESSED 10365/15380 posts
# PROCESSED 10370/15380 posts
# PROCESSED 10375/15380 posts
# PROCESSED 10380/15380 posts
# PROCESSED 10385/15380 posts
# PROCESSED 10390/15380 posts
# PROCESSED 10395/15380 posts
# PROCESSED 10400/15380 posts
# PROCESSED 10405/15380 posts
# PROCESSED 10410/15380 posts
# PROCESSED 10415/15380 posts
# PROCESSED 10420/15380 posts
# PROCESSED 10425/15380 posts
# PROCESSED 10430/15380 posts
# PROCESSED 10435/15380 posts
# PROCESSED 10440/15380 posts
# PROCESSED 10445/15380 posts
# PROCESSED 10450/15380 posts
# PROCESSED 10455/15380 posts
# PROCESSED 10460/15380 posts
# PROCESSED 10465/15380 posts
# PROCESSED 10470/15380 posts
# PROCESSED 10475/15380 posts
# PROCESSED 10480/15380 posts
# PROCESSED 10485/15380 posts
# PROCESSED 10490/15380 posts
# PROCESSED 10495/15380 posts
# PROCESSED 10500/15380 posts
# PROCESSED 10505/15380 posts
# PROCESSED 10510/15380 posts
# PROCESSED 10515/15380 posts
# PROCESSED 10520/15380 posts
# PROCESSED 10525/15380 posts
# PROCESSED 10530/15380 posts
# PROCESSED 10535/15380 posts
# PROCESSED 10540/15380 posts
# PROCESSED 10545/15380 posts
# PROCESSED 10550/15380 posts
# PROCESSED 10555/15380 posts
# PROCESSED 10560/15380 posts
# PROCESSED 10565/15380 posts
# PROCESSED 10570/15380 posts
# PROCESSED 10575/15380 posts
# PROCESSED 10580/15380 posts
# PROCESSED 10585/15380 posts
# PROCESSED 10590/15380 posts
# PROCESSED 10595/15380 posts
# PROCESSED 10600/15380 posts
# PROCESSED 10605/15380 posts
# PROCESSED 10610/15380 posts
# PROCESSED 10615/15380 posts
# PROCESSED 10620/15380 posts
# PROCESSED 10625/15380 posts
# PROCESSED 10630/15380 posts
# PROCESSED 10635/15380 posts
# PROCESSED 10640/15380 posts
# PROCESSED 10645/15380 posts
# PROCESSED 10650/15380 posts
# PROCESSED 10655/15380 posts
# PROCESSED 10660/15380 posts
# PROCESSED 10665/15380 posts
# PROCESSED 10670/15380 posts
# PROCESSED 10675/15380 posts
# PROCESSED 10680/15380 posts
# PROCESSED 10685/15380 posts
# PROCESSED 10690/15380 posts
# PROCESSED 10695/15380 posts
# PROCESSED 10700/15380 posts
# PROCESSED 10705/15380 posts
# PROCESSED 10710/15380 posts
# PROCESSED 10715/15380 posts
# PROCESSED 10720/15380 posts
# PROCESSED 10725/15380 posts
# PROCESSED 10730/15380 posts
# PROCESSED 10735/15380 posts
# PROCESSED 10740/15380 posts
# PROCESSED 10745/15380 posts
# PROCESSED 10750/15380 posts
# PROCESSED 10755/15380 posts
# PROCESSED 10760/15380 posts
# PROCESSED 10765/15380 posts
# PROCESSED 10770/15380 posts
# PROCESSED 10775/15380 posts
# PROCESSED 10780/15380 posts
# PROCESSED 10785/15380 posts
# PROCESSED 10790/15380 posts
# PROCESSED 10795/15380 posts
# PROCESSED 10800/15380 posts
# PROCESSED 10805/15380 posts
# PROCESSED 10810/15380 posts
# PROCESSED 10815/15380 posts
# PROCESSED 10820/15380 posts
# PROCESSED 10825/15380 posts
# PROCESSED 10830/15380 posts
# PROCESSED 10835/15380 posts
# PROCESSED 10840/15380 posts
# PROCESSED 10845/15380 posts
# PROCESSED 10850/15380 posts
# PROCESSED 10855/15380 posts
# PROCESSED 10860/15380 posts
# PROCESSED 10865/15380 posts
# PROCESSED 10870/15380 posts
# PROCESSED 10875/15380 posts
# PROCESSED 10880/15380 posts
# PROCESSED 10885/15380 posts
# PROCESSED 10890/15380 posts
# PROCESSED 10895/15380 posts
# PROCESSED 10900/15380 posts
# PROCESSED 10905/15380 posts
# PROCESSED 10910/15380 posts
# PROCESSED 10915/15380 posts
# PROCESSED 10920/15380 posts
# PROCESSED 10925/15380 posts
# PROCESSED 10930/15380 posts
# PROCESSED 10935/15380 posts
# PROCESSED 10940/15380 posts
# PROCESSED 10945/15380 posts
# PROCESSED 10950/15380 posts
# PROCESSED 10955/15380 posts
# PROCESSED 10960/15380 posts
# PROCESSED 10965/15380 posts
# PROCESSED 10970/15380 posts
# PROCESSED 10975/15380 posts
# PROCESSED 10980/15380 posts
# PROCESSED 10985/15380 posts
# PROCESSED 10990/15380 posts
# PROCESSED 10995/15380 posts
# PROCESSED 11000/15380 posts

# %%
def process_post(post):
    
    user = post.find('div',{'class':'author'})
    user_id = int(user.find('a',{'class':'username'}).get('href').split('/')[-1])
    
    # Add user to db if does not exist 
    if users.find({'id': user_id}).count() < 1:
        name = user.find('a',{'class':'username'}).text.strip()
        title = user.find_all('em')[0].text.strip().lower()
        site = user.find_all('em')[-1].text.strip().lower()
        posts = int(user.find('div',{'class':'stats'}).find('a').text.strip().lower())
        users.insert_one({'id':user_id,'name':name,'title':title,'site':site, 'posts':posts })
        
    # Extract date
    date = get_date(post)
    
    # Extract text
    text = ' '.join([txt.text.lower() for txt in post.find('div',{'itemprop':'description'}).find_all('p')])
    
    return user_id, text, date

# %%
import re
import datetime as dt
months = ['january','february','march','april','may','june','july','august','september','october','november','december']

def get_date(post):
    
    regexes = ['(\d+) day','(\d+) month', '(\w+) (\d+), (20\d+)']
    raw_date = post.find('div',{'class':'date'}).text.strip()
    date = None
    
    for idx, reg in enumerate(regexes):
        matches = re.search(reg, raw_date)
        if matches:
            if idx == 0:
                date = dt.datetime.now() - dt.timedelta(days=int(matches.group(1)))
            elif idx == 1:
                date = dt.datetime.now() - dt.timedelta(days=int(matches.group(1))*30)
            else:
                date = dt.datetime(int(matches.group(3)), int(months.index(matches.group(1).lower())) + 1, int(matches.group(2)))

    return date.strftime('%Y-%m-%d') if date else 'WHY'
